# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
train = pd.read_csv('data/201901-202003.csv')

# %%
# 변수이름
## CARD_SIDO_NM  : 카드이용지역_시도 (가맹점 주소 기준)
## CARD_CCG_NM   : 카드이용지역_시군구 (가맹점 주소 기준)
## STD_CLSS_NM    : 업종명
## HOM_SIDO_NM    : 거주지역_시도 (고객 집주소 기준)
## HOM_CCG_NM     : 거주지역_시군구 (고객 집주소 기준)
## AGE                       : 나이
## SEX_CTGO_CD    : 성별 (1: 남성, 2: 여성)
## FLC             :  가구생애주기 (1: 1인가구, 2: 영유아자녀가구, 3: 중고생자녀가구, 4: 성인자녀가구, 5: 노년가구)
## CSTMR_CNT   :    이용고객수 (명)
## AMT            : 이용금액 (원)
## CNT            : 이용건수 (건)
## year            0
## month           0

# %%
train
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 0           201901           강원         강릉시  건강보조식품 소매업          강원
# 1           201901           강원         강릉시  건강보조식품 소매업          강원
# 2           201901           강원         강릉시  건강보조식품 소매업          강원
# 3           201901           강원         강릉시  건강보조식품 소매업          강원
# 4           201901           강원         강릉시  건강보조식품 소매업          강원
# ...            ...          ...         ...         ...         ...
# 24697787    202003           충북         충주시    휴양콘도 운영업          충북
# 24697788    202003           충북         충주시    휴양콘도 운영업          충북
# 24697789    202003           충북         충주시    휴양콘도 운영업          충북
# 24697790    202003           충북         충주시    휴양콘도 운영업          충북
# 24697791    202003           충북         충주시    휴양콘도 운영업          충북
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0               강릉시  20s            1    1          4   311200    4
# ...

# %%
train.isnull().sum()
# Out:
# REG_YYMM             0
# CARD_SIDO_NM         0
# CARD_CCG_NM      87213
# STD_CLSS_NM          0
# HOM_SIDO_NM          0
# HOM_CCG_NM      147787
# AGE                  0
# SEX_CTGO_CD          0
# FLC                  0
# CSTMR_CNT            0
# AMT                  0
# CNT                  0
# dtype: int64

# %%
train['year'] = train['REG_YYMM'].apply(lambda x: int(str(x)[:4]))
train['month'] = train['REG_YYMM'].apply(lambda x: int(str(x)[4:]))

# %%
train = train.drop(['REG_YYMM'], axis=1)
train
# Out:
#          CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0                  강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1                  강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2                  강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3                  강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4                  강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# ...               ...         ...         ...         ...        ...  ...
# 24697787           충북         충주시    휴양콘도 운영업          충북        충주시  30s
# 24697788           충북         충주시    휴양콘도 운영업          충북        충주시  40s
# 24697789           충북         충주시    휴양콘도 운영업          충북        충주시  50s
# 24697790           충북         충주시    휴양콘도 운영업          충북        충주시  50s
# 24697791           충북         충주시    휴양콘도 운영업          충북        충주시  60s
#
#           SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT  year  month
# ...

# %%
train.tail(30)
# Out:
#          CARD_SIDO_NM CARD_CCG_NM    STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 24697762           충북         충주시            호텔업          충북        충주시  60s
# 24697763           충북         충주시            호텔업          충북        충주시  70s
# 24697764           충북         충주시            호텔업          충북        충주시  70s
# 24697765           충북         충주시  화장품 및 방향제 소매업          충북        음성군  50s
# 24697766           충북         충주시  화장품 및 방향제 소매업          충북    청주시 흥덕구  20s
# 24697767           충북         충주시  화장품 및 방향제 소매업          충북        충주시  10s
# 24697768           충북         충주시  화장품 및 방향제 소매업          충북        충주시  20s
# 24697769           충북         충주시  화장품 및 방향제 소매업          충북        충주시  20s
# 24697770           충북         충주시  화장품 및 방향제 소매업          충북        충주시  20s
# 24697771           충북         충주시  화장품 및 방향제 소매업          충북        충주시  30s
# 24697772           충북         충주시  화장품 및 방향제 소매업          충북        충주시  30s
# ...

# %%
len(train.STD_CLSS_NM.unique())
# Out:
# 41

# %%
train.loc[train['CARD_SIDO_NM'] == '제주'].isnull().sum()
# Out:
# CARD_SIDO_NM       0
# CARD_CCG_NM        0
# STD_CLSS_NM        0
# HOM_SIDO_NM        0
# HOM_CCG_NM      3071
# AGE                0
# SEX_CTGO_CD        0
# FLC                0
# CSTMR_CNT          0
# AMT                0
# CNT                0
# year               0
# month              0
# dtype: int64

# %%
print(train.loc[train['HOM_SIDO_NM'] == '제주'].isnull().sum())
# Out:
# CARD_SIDO_NM      0
# CARD_CCG_NM     278
# STD_CLSS_NM       0
# HOM_SIDO_NM       0
# HOM_CCG_NM        0
# AGE               0
# SEX_CTGO_CD       0
# FLC               0
# CSTMR_CNT         0
# AMT               0
# CNT               0
# year              0
# month             0
# dtype: int64

# %%
train['CARD_SIDO_NM'].unique()
# Out:
# array(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종', '울산',
#        '인천', '전남', '전북', '제주', '충남', '충북'], dtype=object)

# %%
for i in train['HOM_SIDO_NM'].unique():
    print(i)
    print(train.loc[train['HOM_SIDO_NM'] == i].isnull().sum())
    print('')
# Out:
# 강원
# CARD_SIDO_NM      0
# CARD_CCG_NM     518
# STD_CLSS_NM       0
# HOM_SIDO_NM       0
# HOM_CCG_NM        0
# AGE               0
# SEX_CTGO_CD       0
# FLC               0
# CSTMR_CNT         0
# AMT               0
# CNT               0
# year              0
# month             0
# dtype: int64
#
# 경기
# CARD_SIDO_NM        0
# CARD_CCG_NM     17732
# STD_CLSS_NM         0
# HOM_SIDO_NM         0
# HOM_CCG_NM          0
# AGE                 0
# SEX_CTGO_CD         0
# FLC                 0
# CSTMR_CNT           0
# AMT                 0
# CNT                 0
# year                0
# month               0
# dtype: int64
#
# 서울
# CARD_SIDO_NM        0
# CARD_CCG_NM     15311
# STD_CLSS_NM         0
# HOM_SIDO_NM         0
# HOM_CCG_NM          0
# AGE                 0
# SEX_CTGO_CD         0
# FLC                 0
# CSTMR_CNT           0
# AMT                 0
# CNT                 0
# year                0
# month               0
# dtype: int64
#
# 경남
# ...

# %%
train.loc[train['HOM_SIDO_NM'] == '제주']['HOM_CCG_NM'].unique()
# Out:
# array(['제주시', '서귀포시'], dtype=object)

# %%
train['CARD_CCG_NM'].fillna('세종시', inplace = True)

# %%
train['HOM_CCG_NM'].fillna('세종시', inplace = True)

# %%
train.isnull().sum()
# Out:
# CARD_SIDO_NM    0
# CARD_CCG_NM     0
# STD_CLSS_NM     0
# HOM_SIDO_NM     0
# HOM_CCG_NM      0
# AGE             0
# SEX_CTGO_CD     0
# FLC             0
# CSTMR_CNT       0
# AMT             0
# CNT             0
# year            0
# month           0
# dtype: int64

# %%
############################################################

# %%
city_amt = train.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM'])['AMT'].sum().reset_index()
city_amt
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0             강원             건강보조식품 소매업    1820824382
# 1             강원                골프장 운영업   51290887138
# 2             강원            과실 및 채소 소매업   16675489268
# 3             강원      관광 민예품 및 선물용품 소매업     457212008
# 4             강원   그외 기타 분류안된 오락관련 서비스업        177000
# ..           ...                    ...           ...
# 645           충북  피자 햄버거 샌드위치 및 유사 음식점업   21294163365
# 646           충북                한식 음식점업  327145423793
# 647           충북                    호텔업     530914357
# 648           충북          화장품 및 방향제 소매업    9175488855
# 649           충북               휴양콘도 운영업    2414736980
#
# [650 rows x 3 columns]

# %%
train['CARD_SIDO_NM'].unique()
# Out:
# array(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종', '울산',
#        '인천', '전남', '전북', '제주', '충남', '충북'], dtype=object)

# %%
train['STD_CLSS_NM'].unique()
# Out:
# array(['건강보조식품 소매업', '골프장 운영업', '과실 및 채소 소매업', '관광 민예품 및 선물용품 소매업',
#        '그외 기타 스포츠시설 운영업', '그외 기타 종합 소매업', '기타 대형 종합 소매업', '기타 외국식 음식점업',
#        '기타 주점업', '기타음식료품위주종합소매업', '마사지업', '비알콜 음료점업', '빵 및 과자류 소매업',
#        '서양식 음식점업', '수산물 소매업', '슈퍼마켓', '스포츠 및 레크레이션 용품 임대업', '여관업', '욕탕업',
#        '육류 소매업', '일반유흥 주점업', '일식 음식점업', '전시 및 행사 대행업', '중식 음식점업',
#        '차량용 가스 충전업', '차량용 주유소 운영업', '체인화 편의점', '피자 햄버거 샌드위치 및 유사 음식점업',
#        '한식 음식점업', '호텔업', '화장품 및 방향제 소매업', '휴양콘도 운영업', '여행사업', '자동차 임대업',
#        '면세점', '버스 운송업', '택시 운송업', '기타 수상오락 서비스업', '내항 여객 운송업',
#        '그외 기타 분류안된 오락관련 서비스업', '정기 항공 운송업'], dtype=object)

# %%
for i in train['CARD_SIDO_NM'].unique():
    print(i, set(train['STD_CLSS_NM'].unique()) - set(city_amt.loc[city_amt['CARD_SIDO_NM'] == i]['STD_CLSS_NM']))
# Out:
# 강원 {'정기 항공 운송업'}
# 경기 {'정기 항공 운송업', '면세점'}
# 경남 {'정기 항공 운송업', '면세점'}
# 경북 {'정기 항공 운송업', '면세점'}
# 광주 {'휴양콘도 운영업', '그외 기타 분류안된 오락관련 서비스업', '정기 항공 운송업', '면세점'}
# 대구 {'내항 여객 운송업', '휴양콘도 운영업', '그외 기타 분류안된 오락관련 서비스업', '정기 항공 운송업'}
# 대전 {'버스 운송업', '그외 기타 분류안된 오락관련 서비스업', '휴양콘도 운영업', '면세점', '택시 운송업', '정기 항공 운송업', '내항 여객 운송업'}
# 부산 {'그외 기타 분류안된 오락관련 서비스업'}
# 서울 {'휴양콘도 운영업', '그외 기타 분류안된 오락관련 서비스업'}
# 세종 {'버스 운송업', '자동차 임대업', '호텔업', '휴양콘도 운영업', '면세점', '택시 운송업', '정기 항공 운송업', '내항 여객 운송업', '여행사업'}
# 울산 {'내항 여객 운송업', '휴양콘도 운영업', '정기 항공 운송업'}
# 인천 {'버스 운송업', '휴양콘도 운영업', '그외 기타 분류안된 오락관련 서비스업'}
# 전남 {'정기 항공 운송업'}
# 전북 {'그외 기타 분류안된 오락관련 서비스업', '면세점'}
# 제주 {'버스 운송업'}
# 충남 {'면세점'}
# 충북 {'정기 항공 운송업', '그외 기타 분류안된 오락관련 서비스업'}

# %%
len(train.loc[train['CARD_SIDO_NM'] == '울산']['STD_CLSS_NM'].unique())
# Out:
# 38

# %%
len(train.loc[train['CARD_SIDO_NM'] == '세종']['STD_CLSS_NM'].unique())
# Out:
# 32

# %% [markdown]
# ### 여행객 vs 거주자

# %%
df_stay = train.loc[train['CARD_SIDO_NM'] == train['HOM_SIDO_NM']]
df_stay
# Out:
#          CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 0                  강원         강릉시  건강보조식품 소매업          강원        강릉시  20s
# 1                  강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 2                  강원         강릉시  건강보조식품 소매업          강원        강릉시  30s
# 3                  강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# 4                  강원         강릉시  건강보조식품 소매업          강원        강릉시  40s
# ...               ...         ...         ...         ...        ...  ...
# 24697787           충북         충주시    휴양콘도 운영업          충북        충주시  30s
# 24697788           충북         충주시    휴양콘도 운영업          충북        충주시  40s
# 24697789           충북         충주시    휴양콘도 운영업          충북        충주시  50s
# 24697790           충북         충주시    휴양콘도 운영업          충북        충주시  50s
# 24697791           충북         충주시    휴양콘도 운영업          충북        충주시  60s
#
#           SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT  year  month
# ...

# %%
df_stay['STD_CLSS_NM'].unique()
# Out:
# array(['건강보조식품 소매업', '골프장 운영업', '과실 및 채소 소매업', '관광 민예품 및 선물용품 소매업',
#        '그외 기타 스포츠시설 운영업', '그외 기타 종합 소매업', '기타 대형 종합 소매업', '기타 외국식 음식점업',
#        '기타 주점업', '기타음식료품위주종합소매업', '마사지업', '비알콜 음료점업', '빵 및 과자류 소매업',
#        '서양식 음식점업', '수산물 소매업', '슈퍼마켓', '스포츠 및 레크레이션 용품 임대업', '여관업', '욕탕업',
#        '육류 소매업', '일반유흥 주점업', '일식 음식점업', '전시 및 행사 대행업', '중식 음식점업',
#        '차량용 가스 충전업', '차량용 주유소 운영업', '체인화 편의점', '피자 햄버거 샌드위치 및 유사 음식점업',
#        '한식 음식점업', '화장품 및 방향제 소매업', '휴양콘도 운영업', '여행사업', '자동차 임대업', '호텔업',
#        '면세점', '택시 운송업', '기타 수상오락 서비스업', '내항 여객 운송업', '버스 운송업',
#        '그외 기타 분류안된 오락관련 서비스업', '정기 항공 운송업'], dtype=object)

# %%
len(df_stay['CARD_SIDO_NM'].unique())
# Out:
# 17

# %%
city_count = df_stay.groupby(['CARD_SIDO_NM', 'STD_CLSS_NM'])['AMT'].mean().reset_index()
city_count
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM        AMT
# 0             강원             건강보조식품 소매업 1346506.68
# 1             강원                골프장 운영업 1999634.00
# 2             강원            과실 및 채소 소매업 1669710.46
# 3             강원      관광 민예품 및 선물용품 소매업  206116.43
# 4             강원        그외 기타 스포츠시설 운영업  492228.82
# ..           ...                    ...        ...
# 640           충북  피자 햄버거 샌드위치 및 유사 음식점업 1388814.17
# 641           충북                한식 음식점업 9541441.28
# 642           충북                    호텔업  611978.13
# 643           충북          화장품 및 방향제 소매업 1391570.56
# 644           충북               휴양콘도 운영업  435132.18
#
# [645 rows x 3 columns]

# %%
list(df_stay['STD_CLSS_NM'].unique()) - list(city_count.loc[city_count['CARD_SIDO_NM'] == '강원']['STD_CLSS_NM'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-4db3d47c49d2> in <module>
# ----> 1 list(df_stay['STD_CLSS_NM'].unique()) - list(city_count.loc[city_count['CARD_SIDO_NM'] == '강원']['STD_CLSS_NM'])
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
a = [item for item in list(df_stay['STD_CLSS_NM'].unique()) if item not in list(city_count.loc[city_count['CARD_SIDO_NM'] == '강원']['STD_CLSS_NM'])]

# %%
a
# Out:
# ['그외 기타 분류안된 오락관련 서비스업', '정기 항공 운송업']

# %%
type(df_stay['STD_CLSS_NM'].unique())
# Out:
# numpy.ndarray

# %%
type(city_count.loc[city_count['CARD_SIDO_NM'] == '강원']['STD_CLSS_NM'])
# Out:
# pandas.core.series.Series

# %%
# Out:
#     CARD_SIDO_NM            STD_CLSS_NM        AMT
# 0             강원             건강보조식품 소매업 1230286.74
# 1             강원                골프장 운영업 1598394.69
# 2             강원            과실 및 채소 소매업  614108.02
# 3             강원      관광 민예품 및 선물용품 소매업  103254.74
# 4             강원   그외 기타 분류안된 오락관련 서비스업   88500.00
# ..           ...                    ...        ...
# 645           충북  피자 햄버거 샌드위치 및 유사 음식점업  590209.36
# 646           충북                한식 음식점업 1597374.17
# 647           충북                    호텔업  406208.38
# 648           충북          화장품 및 방향제 소매업 1232436.38
# 649           충북               휴양콘도 운영업  455782.74
#
# [650 rows x 3 columns]

# %%
for i in

# %%
df_travel = train.loc[train['CARD_SIDO_NM'] != train['HOM_SIDO_NM']]
df_travel
# Out:
#          CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM HOM_CCG_NM  AGE  \
# 25                 강원         강릉시     골프장 운영업          경기    성남시 분당구  50s
# 26                 강원         강릉시     골프장 운영업          경기    성남시 분당구  60s
# 27                 강원         강릉시     골프장 운영업          경기    안산시 단원구  40s
# 28                 강원         강릉시     골프장 운영업          경기    용인시 기흥구  50s
# 29                 강원         강릉시     골프장 운영업          경기    용인시 수지구  50s
# ...               ...         ...         ...         ...        ...  ...
# 24697750           충북         충주시         호텔업          경기       남양주시  50s
# 24697751           충북         충주시         호텔업          경기    성남시 분당구  60s
# 24697752           충북         충주시         호텔업          경기    성남시 분당구  60s
# 24697753           충북         충주시         호텔업          경기        오산시  50s
# 24697754           충북         충주시         호텔업          경북        문경시  60s
#
#           SEX_CTGO_CD  FLC  CSTMR_CNT     AMT  CNT  year  month
# ...

# %%
# 14976546 여행객
#  9721246 거주자

# %%
df_list = [df_stay, df_travel]
